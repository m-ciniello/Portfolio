# %%
import pyodbc
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
from time import time

# %%
def rt(start=False):
    if start:
        return time() - t0
    else:
        return time()

# %%
t0 = rt()
import numpy
np.random.rand

# %%
server = 'CAEDCDB02'
database = 'POC'

#MUST INSTALL OBCD DRIVER FOR THIS TO WORK
#conn = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL Server};SERVER=CAEDCDB02;Trusted_Connection=yes;DATABASE=POC;UID=CA\\mciniello')
#Becuase 'Authentication' = Windows Authertication, must pass 'Trusted_Connection'=yes
t0 = time()
connection = pyodbc.connect('DRIVER={ODBC Driver 13 for SQL server};SERVER='+server+';Trusted_Connection=yes;DATABASE='+database)
cursor = connection.cursor()

query = '''SELECT *
FROM POC.dbo.PartnerClientData
'''

# GET DATA
cursor.execute(query)
x = cursor.fetchall()

print("Runtime: {0} seconds".format(time() - t0))

# %%
x[0]
# Out:
# ('1000467874', '1000004132', 4497, 5001095606, 'CA25527', 'Elaine Cheung', 'James', 'A.', 'Speakman', 'jspeakman@cwilson.com', 'Partner', 'Clark Wilson Llp', '900 - 885 West Georgia Street', 'Vancouver', 'BC', 'V6C 3H1', 'Canada', '604-891-7739', Decimal('4.53'), 'Moderate', '23')

# %%
# GET COLUMNS
columns = [x[0] for x in cursor.description]

# %%
# PUT DATA INTO DATAFRAME
df_orig = pd.DataFrame(np.array(x), columns=columns)
df_orig.shape
# Out:
# (332775, 21)

# %%
df_orig
# Out:
#        IBSContactID IBSEntityID TRContactID TRCompanyID EmployeeID  \
# 0        1000467874  1000004132        4497  5001095606    CA25527
# 1        1000467874  1000004132        4497  5001095606    CA11815
# 2        1000467874  1000004132        4497  5001095606    CA12274
# 3        1000467874  1000004132        4497  5001095606    CA12599
# 4        1000467874  1000004132        4497  5001095606    CA12404
# 5        1000467874  1000004132        4497  5001095606    CA30654
# 6        1000467874  1000004132        4497  5001095606    CA12461
# 7        1000467874  1000004132        4497  5001095606    CA12313
# 8        1000467874  1000004132        4497  5001095606    CA12339
# 9        1000467874  1000004132        4497  5001095606    CA39464
# 10       1000136538  1000005001        4511      226870    CA12404
# 11       1000136538  1000005001        4511      226870    CA12216
# 12       1000136538  1000005001        4511      226870    CA39505
# ...
